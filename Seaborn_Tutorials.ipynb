# %% [markdown]
# # Intro

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.get_dataset_names()      #Seaborn provides these pre-processed data sets in itself:
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\Admin\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %% [markdown]
# ## Loading inbuilt dataset

# %%
tips = sns.load_dataset('tips')     
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ## factorplot
# factorplot is the most general form of a categorical plot. It can take in a kind parameter to adjust the plot type

# %%
sns.factorplot(x='sex',y='total_bill',data=tips)
#kind=“point”, “bar”, “strip” (Default), “swarm”, “box”, “violin”, or “boxen”.
sns.factorplot(x='sex',y='total_bill',data=tips,kind='bar')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # Bar Plots

# %% [markdown]
# ## Draw a bar chart

# %%
sns.barplot(x='day', y='total_bill', data=tips)           
#plt.show() # to remove the header in o/p

# %% [markdown]
# ## Changing color of all bars

# %%
sns.barplot(x='day', y='total_bill', color= 'green', data=tips)

# %% [markdown]
# ## Changing saturation

# %%
sns.barplot(x='day', y='total_bill', color= 'green', saturation=0.4, data=tips)

# %% [markdown]
# ## Hue attribute

# %%
sns.barplot(x = 'day',y = 'total_bill',hue = 'sex',data = tips)      
#Hue is used to represent categorical column separately. Eg: Male & Female.

# %% [markdown]
# ## Horizontal Bar Plots

# %%
sns.barplot(x = 'total_bill',y = 'day',data = tips)

# %% [markdown]
# ## Changing order

# %%
sns.barplot(x = 'day',y = 'total_bill',order = ['Sun','Fri','Thur','Sat'],data = tips)

# %% [markdown]
# ## Saving plot in file

# %%
sns_bar=sns.barplot(x='day', y='total_bill', data=tips)   
sns_bar

# %%
#saving in notebook itself
fig = sns_bar.get_figure()

# %%
fig.savefig(fname='bar.png')

# %% [markdown]
# ## Changing Estimator

# %%
sns.barplot(x = 'day',y = 'total_bill',estimator=np.median,data = tips)
#Numbers on Y axis are aggregated in terms of mean by default. We changed it to median.
#Here the height of bar represents median value of that bar.

# %% [markdown]
# ## Countplot

# %% [markdown]
# This is essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# ## Confidence Intervals

# %%
sns.barplot(x='day', y='total_bill',palette = 'winter_r', data=tips)

# %%
#Black bars represent CI for that bar.

# %%
sns.barplot(x='day', y='total_bill', ci=60, data=tips) 
#We reduced ci to 60, so the height of the black bar is reduced.

# %%
sns.barplot(x='day', y='total_bill', ci=60, capsize=0.3, data=tips)

# %% [markdown]
# # Palette

# %% [markdown]
# ## Viewing palette

# %%
sns.palplot(sns.color_palette('deep',5))                  #5 denotes no. of colors
sns.palplot(sns.color_palette('bright',15))
#Different Palettes: deep, muted, pastel, bright, dark, spring and colorblind.

# %% [markdown]
# ## Creating custom palettes

# %%
sns.set_palette(['red', 'blue','pink'])

# %%
sns.palplot(sns.color_palette())

# %% [markdown]
# ## Changing pallete

# %%
sns.barplot(x='day', y='total_bill',palette = 'winter_r', data=tips)

# %%
#Black bars represent CI for that bar.

# %%
sns.barplot(x='day', y='total_bill', ci=60, data=tips) 
#We reduced ci to 60, so the height of the black bar is reduced.

# %%
sns.barplot(x='day', y='total_bill', ci=60, capsize=0.3, data=tips)

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# ## Drawing a distribution plot

# %%
sns.distplot(tips.total_bill)

# %%
sns.distplot(tips.total_bill, rug=True) #For rug plot

# %%
sns.distplot(tips.total_bill, kde = False) #For removing kde plot,
#sns.distplot(tips.total_bill, hist = False) #For removing histogram,

# %%
sns.distplot(tips.total_bill, bins=20) #Default no. of bins is 10.

# %% [markdown]
# ## Styling Rugplots

# %%
sns.distplot(tips.total_bill,rug_kws = {'color':'red','height':0.30},rug = True)

# %%
#Rugplot systex
sns.rugplot(tips.total_bill)

#Rugplot: Just like we hammered bins of histogram from top and made them flat. In rugplot, darker the shade we get; higher the histogram bin had been.

# %% [markdown]
# ## Styling Histograms

# %%
sns.distplot(tips.total_bill,kde = False,hist_kws = {'color':'blue','alpha':0.2,'histtype':'stepfilled'})

# %% [markdown]
# ## Styling KDE Plots

# %%
sns.distplot(tips.total_bill,kde = True,hist = False,kde_kws = {'color':'blue','lw':4.0,'alpha':0.9})

# %%
#KDE plots are sum of all the normal distribution of the rug plot.
#KDE Syntex:
sns.kdeplot(tips.total_bill)

# %% [markdown]
# ##  jointplot

# %% [markdown]
# Jointplot() allows you to basically match up two distplots for bivariate data. With your choice of what kind parameter to compare with: “scatter”, “reg”, “resid”, “kde”, “hex”

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')
#sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')
#sns.jointplot(x='total_bill',y='tip',data=tips,kind='resid')
#sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')
#sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %% [markdown]
# ##  pairplot

# %% [markdown]
# pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns).
# It also supports a color hue argument (for categorical columns).

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='sex', palette='spring')

# %% [markdown]
# # Box Plots

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.boxplot(tips.total_bill)
#sns.boxplot(tips.total_bill, orient='v')

# %% [markdown]
# ## X & Y axis

# %%
sns.boxplot(y=tips.total_bill, x=tips.day)

# %% [markdown]
# ## Hue attribute

# %%
sns.boxplot(y=tips.total_bill, x=tips.day, hue=tips.sex)

# %% [markdown]
# ## Horizontal bars

# %%
sns.boxplot(y=tips.day, x=tips.total_bill,hue=tips.sex)
#Interchange x & y and bars will be horizontal.

# %% [markdown]
# ## Ordering of Bars

# %%
sns.boxplot(y=tips.day, x=tips.total_bill,hue=tips.sex, order=['Sun', 'Sat', 'Fri','Thur'])

# %%
sns.boxplot(y=tips.day, x=tips.total_bill,hue=tips.sex, order=['Sun', 'Sat', 'Fri','Thur'], color='g')

# %% [markdown]
# ## Whis property

# %%
sns.boxplot(y=tips.day, x=tips.total_bill,hue=tips.sex, order=['Sun', 'Sat', 'Fri','Thur'], whis=2)

# %% [markdown]
# ## Showcaps property

# %%
#To make showcaps (end bars) visible or invisible

# %%
sns.boxplot(y=tips.day, x=tips.total_bill,hue=tips.sex, order=['Sun', 'Sat', 'Fri','Thur'], showcaps=False)

# %%
sns.distplot(tips['total_bill'])

# %% [markdown]
# ## violinplot

# %% [markdown]
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %%
sns.violinplot(x="day", y="total_bill", data=tips,palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex', palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=tips,hue='sex',split=True, palette='rainbow')
#For understanding split parameter, refer 3rd and 4th line code under stripplot.

# %% [markdown]
# #  Stripplot and Swarmplot

# %% [markdown]
# ## Stripplot

# %% [markdown]
# The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
sns.stripplot(x="day", y="total_bill", data=tips)

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=False)
#When we want only single strip. points will overlap.

# %%
sns.stripplot(x="day", y="total_bill", data=tips, hue="sex")

# %%
sns.stripplot(x="day", y="total_bill", data=tips, hue="sex", split=True)
#Split seperates data given under hue argument.
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:2781: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Swarmplot

# %% [markdown]
# It is a combination of stripplot and violin plot.
#
# The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# ### Combining swamp plot & violin plot

# %%
sns.violinplot(x="day", y="tip", data=tips,palette='rainbow')
sns.swarmplot(x="day", y="tip", data=tips,color='black',size=3)

# %% [markdown]
# # Matrix Plots

# %% [markdown]
# Matrix plots allow you to plot data as color-encoded matrices and can also be used to indicate clusters within the data (later in the machine learning section we will learn how to formally cluster data).

# %% [markdown]
# ## Heat map
# In order for a heatmap to work properly, data should already be in a matrix form, the sns.heatmap function basically just colors it in.

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Matrix form of correlation data:
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
#sns.heatmap(tips.corr(), cmap='coolwarm')

# %%
#For annotation:
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
#To convert it into matrix form
fp = flights.pivot_table(values='passengers',index='month',columns='year')
fp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fp)
# sns.heatmap(fp,cmap='magma',linecolor='white',linewidths=1)

# %% [markdown]
# ## Cluster map
# The clustermap uses hierarchal clustering to produce a clustered version of the heatmap.

# %%
sns.clustermap(fp)

# %% [markdown]
# Notice now how the years and months are no longer in order, instead they are grouped by similarity in value (passenger count). That means we can begin to infer things from this plot, such as August and July being similar (makes sense, since they are both summer travel months)

# %%
# More options to get the information a little clearer like normalization
sns.clustermap(fp,cmap='coolwarm',standard_scale=1)

# %% [markdown]
# # Grids

# %% [markdown]
# Grids are general types of plots that allow you to map plot types to rows and columns of a grid, this helps you create similar plots separated by features.

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Pairgrid
# Pairgrid is a subplot grid for plotting pairwise relationships in a dataset.

# %%
# Just the Grid
sns.PairGrid(iris)    #P&G are in capitals.

# %%
# Then you map to the grid
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
# Map to upper,lower, and diagonal
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species',palette='rainbow')

# %% [markdown]
# ## Facet Grid
# FacetGrid is the general way to create grids of plots based off of a feature:

# %%
tips = sns.load_dataset('tips')

# %%
# Just the Grid
g = sns.FacetGrid(tips, col="time", row="smoker")

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill")

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker",hue='sex')
# Notice how the arguments come after plt.scatter call
g = g.map(plt.scatter, "total_bill", "tip").add_legend()

# %% [markdown]
# ## JointGrid

# %% [markdown]
# JointGrid is the general version for jointplot() type grids

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sns.regplot, sns.distplot)

# %% [markdown]
# # Regression Plots

# %% [markdown]
# [[Only lmplot is covered here. Rest will be covered in ML]]
# lmplot allows you to display linear models, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.

# %% [markdown]
# ## lmplot

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %% [markdown]
# ### Working with Markers

# %% [markdown]
# lmplot kwargs get passed through to regplot which is a more general form of lmplot(). regplot has a scatter_kws parameter that gets passed to plt.scatter. So you want to set the s parameter in that dictionary, which corresponds (a bit confusingly) to the squared markersize. In other words you end up passing a dictionary with the base matplotlib arguments, in this case, s for size of a scatter plot. In general, you probably won't remember this off the top of your head, but instead reference the documentation.

# %%
# http://matplotlib.org/api/markers_api.html
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='coolwarm',
           markers=['o','v'],scatter_kws={'s':100})

# %% [markdown]
# ## Using a Grid

# %% [markdown]
# We can add more variable separation through columns and rows with the use of a grid. Just indicate this with the col or row arguments.

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')
#Instead of seperating with 'hue' command, we seperated it with the help of grid command. For that we use column & row arguments.

# %%
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)
#We can add another seperation variable in 'row' argument.

# %%
# sns.lmplot(x="total_bill", y="tip", row="time", col="day", hue='sex', data=tips)
# If we want 1 more seperation variable, we can use 'hue' argument along with column & row arguments.

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='coolwarm')

# %% [markdown]
# ##  Aspect and Size

# %% [markdown]
# Seaborn figures can have their size and aspect ratio adjusted with the size and aspect parameters.

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',palette='coolwarm',
          aspect=0.6,size=8)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Style & Color

# %% [markdown]
# ## Styles

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('white')        #[white, whitegrid, dark, darkgrid, ticks]
sns.countplot(x='sex',data=tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips,palette='deep')
#Missing: In o/p, spines were supposed to be present on right side awa on top line.

# %% [markdown]
# ## Spine Removal

# %%
sns.countplot(x='sex',data=tips)
sns.despine()
#Missing: Those missing right and top line spines will be removed after using .despine() command.

# %% [markdown]
# ## Size and Aspect

# %% [markdown]
# You can use matplotlib's *plt.figure(figsize=(width,height) * to change the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect.

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',size=2,aspect=4,data=tips)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ##  Scale and Context

# %%
sns.set_context('poster',font_scale=2)
sns.countplot(x='sex',data=tips,palette='coolwarm')
